# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")

data = np.random.randn(1000)

plt.hist(data)
# Out:
# (array([  9.,  35.,  95., 169., 258., 220., 130.,  61.,  20.,   3.]),
#  array([-2.9491032 , -2.33261296, -1.71612272, -1.09963248, -0.48314224,
#          0.133348  ,  0.74983824,  1.36632848,  1.98281872,  2.59930896,
#          3.2157992 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(
    data,
    bins=30,
    alpha=0.5,
    histtype="stepfilled",
    color="steelblue",
    edgecolor="none",
    density=True,
)
# Out:
# (array([0.01459877, 0.        , 0.02919754, 0.04866257, 0.0340638 ,
#         0.08759263, 0.11192391, 0.13138894, 0.21898157, 0.16545274,
#         0.28224291, 0.3747018 , 0.42823062, 0.37956805, 0.44769565,
#         0.38443431, 0.33577174, 0.35037051, 0.24817911, 0.23358034,
#         0.15085397, 0.13138894, 0.11192391, 0.05352883, 0.05352883,
#         0.0340638 , 0.00973251, 0.00486626, 0.00486626, 0.00486626]),
#  array([-2.9491032 , -2.74360645, -2.53810971, -2.33261296, -2.12711621,
#         -1.92161947, -1.71612272, -1.51062597, -1.30512923, -1.09963248,
#         -0.89413573, -0.68863899, -0.48314224, -0.27764549, -0.07214875,
#          0.133348  ,  0.33884475,  0.5443415 ,  0.74983824,  0.95533499,
#          1.16083174,  1.36632848,  1.57182523,  1.77732198,  1.98281872,
#          2.18831547,  2.39381222,  2.59930896,  2.80480571,  3.01030246,
#          3.2157992 ]),
#  [<matplotlib.patches.Polygon at 0x1e3852d0f70>])

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype="stepfilled", alpha=0.3, density=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00658769, 0.00329384, 0.00329384, 0.00329384, 0.00329384,
#         0.01976306, 0.02305691, 0.03952613, 0.04611382, 0.09222763,
#         0.0823461 , 0.11528454, 0.10210917, 0.09881532, 0.13834145,
#         0.18774911, 0.1943368 , 0.15481067, 0.19104296, 0.2239814 ,
#         0.17127989, 0.21739371, 0.16798605, 0.14492914, 0.19763065,
#         0.12187223, 0.10869685, 0.0823461 , 0.07575841, 0.07246457,
#         0.05928919, 0.03952613, 0.04940766, 0.01646922, 0.02305691,
#         0.        , 0.00658769, 0.00329384, 0.00329384, 0.00329384]),
#  array([-3.01626377, -2.71266713, -2.40907049, -2.10547385, -1.80187721,
#         -1.49828057, -1.19468393, -0.89108729, -0.58749064, -0.283894  ,
#          0.01970264,  0.32329928,  0.62689592,  0.93049256,  1.2340892 ,
#          1.53768584,  1.84128248,  2.14487912,  2.44847577,  2.75207241,
#          3.05566905,  3.35926569,  3.66286233,  3.96645897,  4.27005561,
#          4.57365225,  4.87724889,  5.18084554,  5.48444218,  5.78803882,
#          6.09163546,  6.3952321 ,  6.69882874,  7.00242538,  7.30602202,
#          7.60961866,  7.91321531,  8.21681195,  8.52040859,  8.82400523,
#          9.12760187]),
#  [<matplotlib.patches.Polygon at 0x1e3852d1b40>])

# %%
#Only count bins, do not show hist
counts, bin_edges = np.histogram(data,bins=5)
print(counts)
# Out:
# [ 44 264 478 191  23]

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x,y = np.random.multivariate_normal(mean,cov,10000).T
plt.hist2d(x,y,bins=30,cmap='Blues')
cb=plt.colorbar()
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x,y,bins=30)

plt.hexbin(x,y,gridsize=30,cmap='Blues')
cb=plt.colorbar(label='counts in bin')

# %%
from scipy.stats import gaussian_kde

data = np.vstack([x, y])
kde = gaussian_kde(data)

xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

plt.imshow(
    Z.reshape(Xgrid.shape),
    origin="lower",
    aspect="auto",
    extent=[-3.5, 3.5, -6, 6],
    cmap="Blues",
)
cb = plt.colorbar()
cb.set_label("density")

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
