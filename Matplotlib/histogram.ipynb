# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")

data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  1.,   3.,  27.,  90., 212., 270., 232., 130.,  29.,   6.]),
#  array([-4.16570797, -3.428173  , -2.69063803, -1.95310306, -1.21556809,
#         -0.47803312,  0.25950185,  0.99703682,  1.73457179,  2.47210676,
#          3.20964174]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(
    data,
    bins=30,
    alpha=0.5,
    histtype="stepfilled",
    color="steelblue",
    edgecolor="none",
    density=True,
)
# Out:
# (array([0.0040676 , 0.        , 0.        , 0.        , 0.00813521,
#         0.0040676 , 0.0040676 , 0.04067604, 0.06508166, 0.04474364,
#         0.09762249, 0.22371821, 0.19931258, 0.33354351, 0.3294759 ,
#         0.33761111, 0.37015194, 0.39048996, 0.3294759 , 0.32134069,
#         0.29286747, 0.24405622, 0.17490696, 0.1098253 , 0.05694645,
#         0.03660843, 0.02440562, 0.01220281, 0.00813521, 0.0040676 ]),
#  array([-4.16570797, -3.91986298, -3.67401799, -3.428173  , -3.18232801,
#         -2.93648302, -2.69063803, -2.44479304, -2.19894805, -1.95310306,
#         -1.70725807, -1.46141308, -1.21556809, -0.9697231 , -0.72387811,
#         -0.47803312, -0.23218813,  0.01365686,  0.25950185,  0.50534684,
#          0.75119183,  0.99703682,  1.24288181,  1.4887268 ,  1.73457179,
#          1.98041678,  2.22626177,  2.47210676,  2.71795175,  2.96379675,
#          3.20964174]),
#  [<matplotlib.patches.Polygon at 0x2cd4ff84190>])

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype="stepfilled", alpha=0.3, density=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00321358, 0.00321358, 0.        , 0.00321358, 0.00321358,
#         0.00321358, 0.01928146, 0.00964073, 0.03213577, 0.02570861,
#         0.0546308 , 0.04820365, 0.08676657, 0.10604803, 0.12854306,
#         0.13175664, 0.14461095, 0.17353314, 0.18960102, 0.18960102,
#         0.18960102, 0.17353314, 0.17353314, 0.26029971, 0.19602817,
#         0.15425168, 0.17674671, 0.10926161, 0.0546308 , 0.11890234,
#         0.0417765 , 0.0546308 , 0.02892219, 0.04499007, 0.03856292,
#         0.01928146, 0.00321358, 0.00964073, 0.00321358, 0.00642715]),
#  array([-3.66162562, -3.35044586, -3.0392661 , -2.72808634, -2.41690658,
#         -2.10572682, -1.79454706, -1.48336731, -1.17218755, -0.86100779,
#         -0.54982803, -0.23864827,  0.07253149,  0.38371125,  0.69489101,
#          1.00607077,  1.31725053,  1.62843029,  1.93961005,  2.2507898 ,
#          2.56196956,  2.87314932,  3.18432908,  3.49550884,  3.8066886 ,
#          4.11786836,  4.42904812,  4.74022788,  5.05140764,  5.3625874 ,
#          5.67376716,  5.98494692,  6.29612667,  6.60730643,  6.91848619,
#          7.22966595,  7.54084571,  7.85202547,  8.16320523,  8.47438499,
#          8.78556475]),
#  [<matplotlib.patches.Polygon at 0x2cd50008640>])

# %%
#Only count bins, do not show hist
counts, bin_edges = np.histogram(data,bins=5)
print(counts)
# Out:
# [  4 117 482 362  35]

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x,y = np.random.multivariate_normal(mean,cov,10000).T
plt.hist2d(x,y,bins=30,cmap='Blues')
cb=plt.colorbar()
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x,y,bins=30)

plt.hexbin(x,y,gridsize=30,cmap='Blues')
cb=plt.colorbar(label='counts in bin')

# %%
from scipy.stats import gaussian_kde

data = np.vstack([x, y])
kde = gaussian_kde(data)

xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))
